# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv("bank_marketing_updated_v1.csv")
df.head()
# Out:
# C:\Users\khurr\AppData\Local\Temp\ipykernel_25584\296968265.py:1: DtypeWarning: Columns (0,1,2,3,11,14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("bank_marketing_updated_v1.csv")
#       banking marketing Unnamed: 1                    Unnamed: 2 Unnamed: 3  \
# 0  customer id and age.        NaN  Customer salary and balance.        NaN
# 1            customerid        age                        salary    balance
# 2                     1         58                        100000       2143
# 3                     2         44                         60000         29
# 4                     3         33                        120000          2
#
#                                           Unnamed: 4              Unnamed: 5  \
# 0  Customer marital status and job with education...                     NaN
# 1                                            marital                  jobedu
# ...

# %%
df=pd.read_csv("bank_marketing_updated_v1.csv",skiprows=2)
df.head()
# Out:
#    customerid   age  salary  balance  marital                  jobedu  \
# 0           1  58.0  100000     2143  married     management,tertiary
# 1           2  44.0   60000       29   single    technician,secondary
# 2           3  33.0  120000        2  married  entrepreneur,secondary
# 3           4  47.0   20000     1506  married     blue-collar,unknown
# 4           5  33.0       0        1   single         unknown,unknown
#
#   targeted default housing loan  contact  day      month duration  campaign  \
# 0      yes      no     yes   no  unknown    5  may, 2017  261 sec         1
# 1      yes      no     yes   no  unknown    5  may, 2017  151 sec         1
# 2      yes      no     yes  yes  unknown    5  may, 2017   76 sec         1
# 3       no      no     yes   no  unknown    5  may, 2017   92 sec         1
# 4       no      no      no   no  unknown    5  may, 2017  198 sec         1
#
#    pdays  previous poutcome response
# 0     -1         0  unknown       no
# ...

# %%
df.drop("customerid",axis=1,inplace=True)
df.head()
# Out:
#     age  salary  balance  marital                  jobedu targeted default  \
# 0  58.0  100000     2143  married     management,tertiary      yes      no
# 1  44.0   60000       29   single    technician,secondary      yes      no
# 2  33.0  120000        2  married  entrepreneur,secondary      yes      no
# 3  47.0   20000     1506  married     blue-collar,unknown       no      no
# 4  33.0       0        1   single         unknown,unknown       no      no
#
#   housing loan  contact  day      month duration  campaign  pdays  previous  \
# 0     yes   no  unknown    5  may, 2017  261 sec         1     -1         0
# 1     yes   no  unknown    5  may, 2017  151 sec         1     -1         0
# 2     yes  yes  unknown    5  may, 2017   76 sec         1     -1         0
# 3     yes   no  unknown    5  may, 2017   92 sec         1     -1         0
# 4      no   no  unknown    5  may, 2017  198 sec         1     -1         0
#
#   poutcome response
# 0  unknown       no
# ...

# %%
## Dividing JobEdu into job And Edu

# %%
df['job']=df.jobedu.apply(lambda x: x.split(",")[0])
df.head()
# Out:
#     age  salary  balance  marital                  jobedu targeted default  \
# 0  58.0  100000     2143  married     management,tertiary      yes      no
# 1  44.0   60000       29   single    technician,secondary      yes      no
# 2  33.0  120000        2  married  entrepreneur,secondary      yes      no
# 3  47.0   20000     1506  married     blue-collar,unknown       no      no
# 4  33.0       0        1   single         unknown,unknown       no      no
#
#   housing loan  contact  day      month duration  campaign  pdays  previous  \
# 0     yes   no  unknown    5  may, 2017  261 sec         1     -1         0
# 1     yes   no  unknown    5  may, 2017  151 sec         1     -1         0
# 2     yes  yes  unknown    5  may, 2017   76 sec         1     -1         0
# 3     yes   no  unknown    5  may, 2017   92 sec         1     -1         0
# 4      no   no  unknown    5  may, 2017  198 sec         1     -1         0
#
#   poutcome response           job
# ...

# %%
df['Education']=df.jobedu.apply(lambda x: x.split(",")[1])
df.head()
# Out:
#     age  salary  balance  marital                  jobedu targeted default  \
# 0  58.0  100000     2143  married     management,tertiary      yes      no
# 1  44.0   60000       29   single    technician,secondary      yes      no
# 2  33.0  120000        2  married  entrepreneur,secondary      yes      no
# 3  47.0   20000     1506  married     blue-collar,unknown       no      no
# 4  33.0       0        1   single         unknown,unknown       no      no
#
#   housing loan  contact  day      month duration  campaign  pdays  previous  \
# 0     yes   no  unknown    5  may, 2017  261 sec         1     -1         0
# 1     yes   no  unknown    5  may, 2017  151 sec         1     -1         0
# 2     yes  yes  unknown    5  may, 2017   76 sec         1     -1         0
# 3     yes   no  unknown    5  may, 2017   92 sec         1     -1         0
# 4      no   no  unknown    5  may, 2017  198 sec         1     -1         0
#
#   poutcome response           job  Education
# ...

# %%
df.drop('jobedu',axis=1,inplace=True)
df.head()
# Out:
#     age  salary  balance  marital targeted default housing loan  contact  day  \
# 0  58.0  100000     2143  married      yes      no     yes   no  unknown    5
# 1  44.0   60000       29   single      yes      no     yes   no  unknown    5
# 2  33.0  120000        2  married      yes      no     yes  yes  unknown    5
# 3  47.0   20000     1506  married       no      no     yes   no  unknown    5
# 4  33.0       0        1   single       no      no      no   no  unknown    5
#
#        month duration  campaign  pdays  previous poutcome response  \
# 0  may, 2017  261 sec         1     -1         0  unknown       no
# 1  may, 2017  151 sec         1     -1         0  unknown       no
# 2  may, 2017   76 sec         1     -1         0  unknown       no
# 3  may, 2017   92 sec         1     -1         0  unknown       no
# 4  may, 2017  198 sec         1     -1         0  unknown       no
#
#             job  Education
# 0    management   tertiary
# 1    technician  secondary
# ...

# %%
# Split the Month And Year

# %%
## Since it contains some Missing Values So It cant Be Splitted Without Filtering The data

# %%
##df['Month']=df.month.apply(lambda x: x.split(",")[0])
##df.head()

# %%
## So lets Check For The Float Values in Month

# %%
df[df.month.apply(lambda x: isinstance(x,float))== True]
# Out:
#         age  salary  balance   marital targeted default housing loan  \
# 189    31.0  100000        0    single       no      no     yes   no
# 769    39.0   20000      245   married      yes      no     yes   no
# 860    33.0   55000      165   married      yes      no      no   no
# 1267   36.0   50000      114   married      yes      no     yes  yes
# 1685   34.0   20000      457   married      yes      no     yes   no
# 1899   49.0   16000      164  divorced      yes      no     yes   no
# 2433   26.0   60000     3825   married      yes      no     yes   no
# 2612   38.0   50000      446    single       no      no     yes   no
# 2747   48.0  120000     2550   married       no      no     yes   no
# 3556   41.0   20000       59   married      yes      no     yes   no
# 3890   56.0   55000     4391   married       no      no     yes   no
# 5311   22.0   20000        0    single      yes      no     yes   no
# 6265   32.0   50000       13    single      yes      no     yes   no
# ...

# %%
#Since It does Not contain Any Float VAlues Lets Check For Missing VAlues

# %%
df.isnull().sum()
# Out:
# age          20
# salary        0
# balance       0
# marital       0
# targeted      0
# default       0
# housing       0
# loan          0
# contact       0
# day           0
# month        50
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# response     30
# job           0
# Education     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 19 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45191 non-null  float64
#  1   salary     45211 non-null  int64
#  2   balance    45211 non-null  int64
#  3   marital    45211 non-null  object
#  4   targeted   45211 non-null  object
#  5   default    45211 non-null  object
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45161 non-null  object
#  11  duration   45211 non-null  object
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  response   45181 non-null  object
#  17  job        45211 non-null  object
#  18  Education  45211 non-null  object
# ...

# %%
df.month.value_counts(normalize=True)
# Out:
# month
# may, 2017    0.304400
# jul, 2017    0.152521
# aug, 2017    0.138172
# jun, 2017    0.118133
# nov, 2017    0.087863
# apr, 2017    0.064901
# feb, 2017    0.058590
# jan, 2017    0.031044
# oct, 2017    0.016342
# sep, 2017    0.012754
# mar, 2017    0.010540
# dec, 2017    0.004739
# Name: proportion, dtype: float64

# %%
## Handling missing Values

# %%
 df.age.isnull().sum()
# Out:
# 20

# %%
## check For the percentage Of missing values In data

# %%
float(100.0*20/45211)
# Out:
# 0.04423702196368141

# %%
## since It Only Contains .04 Percent Missing Values So It Is Good To drop  the  Missing Values

# %%
## so Make A copy of Non Null Values In Data

# %%
df1=df[-df.age.isnull()].copy()

# %%
df1.shape
# Out:
# (45191, 19)

# %%
df1.age.isnull().sum()
# Out:
# 0

# %%
## as we can See there is Not Any null Values in the age Column Lets Do it Further For Other Column

# %%
#Handling Missing Values In Month

# %%
df1.month.isnull().sum()
# Out:
# 50

# %%
df1.month.value_counts(normalize=True)
# Out:
# month
# may, 2017    0.304380
# jul, 2017    0.152522
# aug, 2017    0.138123
# jun, 2017    0.118141
# nov, 2017    0.087880
# apr, 2017    0.064908
# feb, 2017    0.058616
# jan, 2017    0.031058
# oct, 2017    0.016327
# sep, 2017    0.012760
# mar, 2017    0.010545
# dec, 2017    0.004741
# Name: proportion, dtype: float64

# %%
month_mode=df1.month.mode()[0]
month_mode
# Out:
# 'may, 2017'

# %%
df1.month.fillna(month_mode,inplace=True)

# %%
df1.month.value_counts(normalize=True)
# Out:
# month
# may, 2017    0.305149
# jul, 2017    0.152353
# aug, 2017    0.137970
# jun, 2017    0.118010
# nov, 2017    0.087783
# apr, 2017    0.064836
# feb, 2017    0.058551
# jan, 2017    0.031024
# oct, 2017    0.016309
# sep, 2017    0.012746
# mar, 2017    0.010533
# dec, 2017    0.004735
# Name: proportion, dtype: float64

# %%
df['Month']=df1.month.apply(lambda x: x.split(",")[0])
df.head()
# Out:
#     age  salary  balance  marital targeted default housing loan  contact  day  \
# 0  58.0  100000     2143  married      yes      no     yes   no  unknown    5
# 1  44.0   60000       29   single      yes      no     yes   no  unknown    5
# 2  33.0  120000        2  married      yes      no     yes  yes  unknown    5
# 3  47.0   20000     1506  married       no      no     yes   no  unknown    5
# 4  33.0       0        1   single       no      no      no   no  unknown    5
#
#        month duration  campaign  pdays  previous poutcome response  \
# 0  may, 2017  261 sec         1     -1         0  unknown       no
# 1  may, 2017  151 sec         1     -1         0  unknown       no
# 2  may, 2017   76 sec         1     -1         0  unknown       no
# 3  may, 2017   92 sec         1     -1         0  unknown       no
# 4  may, 2017  198 sec         1     -1         0  unknown       no
#
#             job  Education Month
# 0    management   tertiary   may
# ...

# %%
df1.pdays.describe()
# Out:
# count    45191.000000
# mean        40.181253
# std        100.074099
# min         -1.000000
# 25%         -1.000000
# 50%         -1.000000
# 75%         -1.000000
# max        871.000000
# Name: pdays, dtype: float64

# %%
df['Year']=df1.month.apply(lambda x: x.split(",")[1])
df.head()
# Out:
#     age  salary  balance  marital targeted default housing loan  contact  day  \
# 0  58.0  100000     2143  married      yes      no     yes   no  unknown    5
# 1  44.0   60000       29   single      yes      no     yes   no  unknown    5
# 2  33.0  120000        2  married      yes      no     yes  yes  unknown    5
# 3  47.0   20000     1506  married       no      no     yes   no  unknown    5
# 4  33.0       0        1   single       no      no      no   no  unknown    5
#
#    ... duration campaign  pdays  previous  poutcome response           job  \
# 0  ...  261 sec        1     -1         0   unknown       no    management
# 1  ...  151 sec        1     -1         0   unknown       no    technician
# 2  ...   76 sec        1     -1         0   unknown       no  entrepreneur
# 3  ...   92 sec        1     -1         0   unknown       no   blue-collar
# 4  ...  198 sec        1     -1         0   unknown       no       unknown
#
#    Education Month   Year
# ...

# %%
df1.drop('month',axis=1,inplace=True)
df.head()
# Out:
#     age  salary  balance  marital targeted default housing loan  contact  day  \
# 0  58.0  100000     2143  married      yes      no     yes   no  unknown    5
# 1  44.0   60000       29   single      yes      no     yes   no  unknown    5
# 2  33.0  120000        2  married      yes      no     yes  yes  unknown    5
# 3  47.0   20000     1506  married       no      no     yes   no  unknown    5
# 4  33.0       0        1   single       no      no      no   no  unknown    5
#
#    ... duration campaign  pdays  previous  poutcome response           job  \
# 0  ...  261 sec        1     -1         0   unknown       no    management
# 1  ...  151 sec        1     -1         0   unknown       no    technician
# 2  ...   76 sec        1     -1         0   unknown       no  entrepreneur
# 3  ...   92 sec        1     -1         0   unknown       no   blue-collar
# 4  ...  198 sec        1     -1         0   unknown       no       unknown
#
#    Education Month   Year
# ...

# %%
## -1 indicates Missing Values!!
## How Do We HAndle This
## Rwmwmber Our Objective!
## . we Want the missing Values To be ignored in the calculations
## Simply Make it Missing Replace -1 with NAN
## all summary Statics - Mwan Median And Mode etc will Ignore the Missing Values

# %%
df1.loc[df1.pdays<0,"pdays"]=np.NaN
df1.pdays.describe()
# Out:
# count    8252.000000
# mean      224.523752
# std       115.202715
# min         1.000000
# 25%       133.000000
# 50%       194.500000
# 75%       327.000000
# max       871.000000
# Name: pdays, dtype: float64

# %%
pdays_mode=df1.pdays.mode()[0]
pdays_mode
# Out:
# 182.0

# %%
#Handling Outliars// Values Beyond Normal values// Univariate Outliers: Single Variable

# %%
## Treatment Of Outliers a) Imputation of Outliers,b) Delete Outliers c) Binning the Values
 ## D) Cap  The Outliers

# %%
## very first Step Is to Find The  Outliers

# %%
df1.age.describe()
# Out:
# count    45191.000000
# mean        40.935651
# std         10.619198
# min         18.000000
# 25%         33.000000
# 50%         39.000000
# 75%         48.000000
# max         95.000000
# Name: age, dtype: float64

# %%
## Since mean And Median Are Not So far Also Difference Between quartiles Are Also significant So 
## Lets Try To Visualise It With Boxpl0t

# %%
sns.boxplot(df1.age)
plt.show()

# %%
df1.salary.describe()
# Out:
# count     45191.000000
# mean      57005.974641
# std       32084.253154
# min           0.000000
# 25%       20000.000000
# 50%       60000.000000
# 75%       70000.000000
# max      120000.000000
# Name: salary, dtype: float64

# %%
sns.boxplot(df1.salary)
plt.show()

# %%
## Balance Variable

# %%
df1.balance.describe()
# Out:
# count     45191.000000
# mean       1362.432520
# std        3045.120417
# min       -8019.000000
# 25%          72.000000
# 50%         448.000000
# 75%        1428.000000
# max      102127.000000
# Name: balance, dtype: float64

# %%
balance_mode=df1.balance.mode()[0]
balance_mode
# Out:
# 0

# %%
plt.figure(figsize=[8,2])
sns.boxplot(df1.balance)
plt.show()

# %%
df1.balance.quantile([0.5,0.7,0.95,0.99])
# Out:
# 0.50      448.0
# 0.70     1126.0
# 0.95     5768.0
# 0.99    13167.1
# Name: balance, dtype: float64

# %%
df1[df1.balance>15000].describe()
# Out:
#               age         salary        balance         day    campaign  \
# count  351.000000     351.000000     351.000000  351.000000  351.000000
# mean    45.341880   70008.547009   24295.780627   16.022792    2.749288
# std     12.114333   34378.272805   12128.560693    8.101819    3.036886
# min     23.000000       0.000000   15030.000000    1.000000    1.000000
# 25%     35.000000   50000.000000   17074.000000    9.000000    1.000000
# 50%     44.000000   60000.000000   20723.000000   18.000000    2.000000
# 75%     55.000000  100000.000000   26254.000000   21.000000    3.000000
# max     84.000000  120000.000000  102127.000000   31.000000   31.000000
#
#             pdays    previous
# count   62.000000  351.000000
# mean   188.516129    0.555556
# std    118.796388    1.784590
# min     31.000000    0.000000
# 25%     96.250000    0.000000
# 50%    167.500000    0.000000
# 75%    246.500000    0.000000
# max    589.000000   23.000000

# %%
## instead of Looking at mean,we could look at quarentiles/medians/percentiles instead

# %%
## Standardising variable

# %%
## lets look at duration variable

# %%
df1.duration.head(10)
# Out:
# 0    261 sec
# 1    151 sec
# 2     76 sec
# 3     92 sec
# 4    198 sec
# 5    139 sec
# 6    217 sec
# 7    380 sec
# 8     50 sec
# 9     55 sec
# Name: duration, dtype: object

# %%
df1.duration.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 45191 entries, 0 to 45210
# Series name: duration
# Non-Null Count  Dtype
# --------------  -----
# 45191 non-null  object
# dtypes: object(1)
# memory usage: 1.7+ MB

# %%
df1.duration.describe()
# Out:
# count       45191
# unique       2646
# top       1.5 min
# freq          138
# Name: duration, dtype: object

# %%
df1.duration=df1.duration.apply(lambda x:float(x.split()[0])/60 if x.find("sec")>0 else float(x.split()[0]))

# %%
df1.duration.describe()
# Out:
# count    45191.000000
# mean         4.303030
# std          4.292739
# min          0.000000
# 25%          1.716667
# 50%          3.000000
# 75%          5.316667
# max         81.966667
# Name: duration, dtype: float64

# %%
## Univariate Analysis- Catogorical Features

# %%
df1.marital.value_counts(normalize=True)
# Out:
# marital
# married     0.601978
# single      0.282932
# divorced    0.115089
# Name: proportion, dtype: float64

# %%
df1.marital.value_counts(normalize=True).plot.barh()
plt.show()

# %%
df1.job.value_counts(normalize= True).plot.barh()

plt.show()

# %%
##Education Variable

# %%
df1.Education.value_counts(normalize=True).plot.barh()
# Out:
# <Axes: ylabel='Education'>

# %%
df1.Education.value_counts(normalize=True).plot.pie()
# Out:
# <Axes: ylabel='proportion'>

# %%
df1.head()
# Out:
#     age  salary  balance  marital targeted default housing loan  contact  day  \
# 0  58.0  100000     2143  married      yes      no     yes   no  unknown    5
# 1  44.0   60000       29   single      yes      no     yes   no  unknown    5
# 2  33.0  120000        2  married      yes      no     yes  yes  unknown    5
# 3  47.0   20000     1506  married       no      no     yes   no  unknown    5
# 4  33.0       0        1   single       no      no      no   no  unknown    5
#
#    duration  campaign  pdays  previous poutcome response           job  \
# 0  4.350000         1    NaN         0  unknown       no    management
# 1  2.516667         1    NaN         0  unknown       no    technician
# 2  1.266667         1    NaN         0  unknown       no  entrepreneur
# 3  1.533333         1    NaN         0  unknown       no   blue-collar
# 4  3.300000         1    NaN         0  unknown       no       unknown
#
#    Education
# 0   tertiary
# 1  secondary
# 2  secondary
# ...

# %%
## Lets Do Univariate Analysis for poutcome variable

# %%
df1.poutcome.value_counts(normalize=True).plot.barh()
# Out:
# <Axes: ylabel='poutcome'>

# %%
## Since There Are To many Unknown Variable So We Need to MAke Unkhown Variable Missing

# %%
df1[-(df1.poutcome=="unknown")].poutcome.value_counts(normalize=True).plot.barh()
# Out:
# <Axes: ylabel='poutcome'>

# %%
## Bivariate Analysis
## NUmerical- =numerical

# %%
plt.scatter(df1.salary, df1.balance)
plt.show()

# %%
df1.plot.scatter(x="age",y="balance")
plt.show()

# %%
##pairplot

# %%
sns.pairplot(data=df1,vars=["salary","balance","age"])
plt.show()
# Out:
# C:\Users\khurr\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Quantify Usinf Correlation Values

# %%
df1[["age","salary","balance"]].corr()
# Out:
#               age    salary   balance
# age      1.000000  0.024374  0.097755
# salary   0.024374  1.000000  0.055505
# balance  0.097755  0.055505  1.000000

# %%
##Correlation Heatmap

# %%
sns.heatmap(df1[["age","salary","balance"]].corr(),annot=True,cmap="Reds")
plt.show()

# %%
# Categorical- Numerical

# %%
df1['salary'].mean()
# Out:
# 57005.974640968336

# %%
df1['response']
# Out:
# 0         no
# 1         no
# 2         no
# 3         no
# 4         no
#         ...
# 45206    yes
# 45207    yes
# 45208    yes
# 45209     no
# 45210     no
# Name: response, Length: 45191, dtype: object

# %%
df1.groupby("response")['salary'].mean()
# Out:
# response
# no     56769.510482
# yes    58780.510880
# Name: salary, dtype: float64

# %%
df1.head()
# Out:
#     age  salary  balance  marital targeted default housing loan  contact  day  \
# 0  58.0  100000     2143  married      yes      no     yes   no  unknown    5
# 1  44.0   60000       29   single      yes      no     yes   no  unknown    5
# 2  33.0  120000        2  married      yes      no     yes  yes  unknown    5
# 3  47.0   20000     1506  married       no      no     yes   no  unknown    5
# 4  33.0       0        1   single       no      no      no   no  unknown    5
#
#    duration  campaign  pdays  previous poutcome response           job  \
# 0  4.350000         1    NaN         0  unknown       no    management
# 1  2.516667         1    NaN         0  unknown       no    technician
# 2  1.266667         1    NaN         0  unknown       no  entrepreneur
# 3  1.533333         1    NaN         0  unknown       no   blue-collar
# 4  3.300000         1    NaN         0  unknown       no       unknown
#
#    Education
# 0   tertiary
# 1  secondary
# 2  secondary
# ...

# %%
df1.groupby("response")['salary'].median()
# Out:
# response
# no     60000.0
# yes    60000.0
# Name: salary, dtype: float64

# %%
sns.boxplot(data=df1,x="response",y="salary")
plt.show()

# %%
df1.groupby('Education')['salary'].aggregate(["mean","median"]).plot.bar()
plt.show()

# %%
df1.groupby('job')['salary'].mean().plot.bar()
plt.show()

# %%
## Categorical - Categorical

# %%
df1.response.value_counts()
# Out:
# response
# no     39876
# yes     5285
# Name: count, dtype: int64

# %%
df.head()
# Out:
#     age  salary  balance  marital targeted default housing loan  contact  day  \
# 0  58.0  100000     2143  married      yes      no     yes   no  unknown    5
# 1  44.0   60000       29   single      yes      no     yes   no  unknown    5
# 2  33.0  120000        2  married      yes      no     yes  yes  unknown    5
# 3  47.0   20000     1506  married       no      no     yes   no  unknown    5
# 4  33.0       0        1   single       no      no      no   no  unknown    5
#
#    ... duration campaign  pdays  previous  poutcome response           job  \
# 0  ...  261 sec        1     -1         0   unknown       no    management
# 1  ...  151 sec        1     -1         0   unknown       no    technician
# 2  ...   76 sec        1     -1         0   unknown       no  entrepreneur
# 3  ...   92 sec        1     -1         0   unknown       no   blue-collar
# 4  ...  198 sec        1     -1         0   unknown       no       unknown
#
#    Education Month   Year
# ...

# %%
## First Convert The Response Value Count To 1 as yes And 0 As no

# %%
df1['response_flag'] = np.where(df1.response=="yes",1,0)

# %%
df1.response_flag.value_counts()
# Out:
# response_flag
# 0    39906
# 1     5285
# Name: count, dtype: int64

# %%
df1.response.value_counts()
# Out:
# response
# no     39876
# yes     5285
# Name: count, dtype: int64

# %%
df1.groupby(['Education'])['response_flag'].mean().plot.barh()
plt.show()

# %%
df1['marital_flag'] = np.where(df1.marital=="married",1,0)

# %%
df1.marital_flag.value_counts()
# Out:
# marital_flag
# 1    27204
# 0    17987
# Name: count, dtype: int64

# %%
df1.groupby(['marital'])['response_flag'].mean().plot.barh()
# Out:
# <Axes: ylabel='marital'>

# %%
df1.groupby(['housing'])['response_flag'].mean().plot.barh()
# Out:
# <Axes: ylabel='housing'>

# %%
df1.groupby(['loan'])['response_flag'].mean().plot.barh()
# Out:
# <Axes: ylabel='loan'>

# %%
df1.groupby(['Education'])['response_flag'].mean().plot.barh()
# Out:
# <Axes: ylabel='Education'>

# %%
df1.groupby('response_flag')['duration'].mean().plot.barh()
# Out:
# <Axes: ylabel='response_flag'>

# %%
res = pd.pivot_table(data=df1, index="Education", columns = "marital", values = "response_flag")
sns.heatmap(res, annot=True, cmap="RdYlGn", center = 0.117)
plt.show()

# %%
res = pd.pivot_table(data=df1, index="job", columns = "marital", values = "response_flag")
sns.heatmap(res, annot=True, cmap="RdYlGn", center = 0.117)
plt.show()

# %%
df1.isnull().sum()
# Out:
# age                  0
# salary               0
# balance              0
# marital              0
# targeted             0
# default              0
# housing              0
# loan                 0
# contact              0
# day                  0
# duration             0
# campaign             0
# pdays            36939
# previous             0
# poutcome             0
# response            30
# job                  0
# Education            0
# response_flag        0
# marital_flag         0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45191 entries, 0 to 45210
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            45191 non-null  float64
#  1   salary         45191 non-null  int64
#  2   balance        45191 non-null  int64
#  3   marital        45191 non-null  object
#  4   targeted       45191 non-null  object
#  5   default        45191 non-null  object
#  6   housing        45191 non-null  object
#  7   loan           45191 non-null  object
#  8   contact        45191 non-null  object
#  9   day            45191 non-null  int64
#  10  duration       45191 non-null  float64
#  11  campaign       45191 non-null  int64
#  12  pdays          8252 non-null   float64
#  13  previous       45191 non-null  int64
#  14  poutcome       45191 non-null  object
#  15  response       45161 non-null  object
#  16  job            45191 non-null  object
# ...

# %%
df1.head(40)
# Out:
#      age  salary  balance   marital targeted default housing loan  contact  \
# 0   58.0  100000     2143   married      yes      no     yes   no  unknown
# 1   44.0   60000       29    single      yes      no     yes   no  unknown
# 2   33.0  120000        2   married      yes      no     yes  yes  unknown
# 3   47.0   20000     1506   married       no      no     yes   no  unknown
# 4   33.0       0        1    single       no      no      no   no  unknown
# 5   35.0  100000      231   married      yes      no     yes   no  unknown
# 6   28.0  100000      447    single       no      no     yes  yes  unknown
# 7   42.0  120000        2  divorced       no     yes     yes   no  unknown
# 8   58.0   55000      121   married      yes      no     yes   no  unknown
# 9   43.0   60000      593    single      yes      no     yes   no  unknown
# 10  41.0   50000      270  divorced      yes      no     yes   no  unknown
# ...
